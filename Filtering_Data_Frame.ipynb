# %% [markdown]
# # Filtering Headers

# %%
import requests
import pandas as pd

#VARIABLES DECLARATION
url = "https://jsearch.p.rapidapi.com/search"

querystring = {"query":"Data Engineer in Ontario, Canada","page":"1","num_pages":"20","date_posted":"month",
              "remote_jobs_only":"true","job_requirements":"under_3_years_experience"}

headers = {
	"X-RapidAPI-Key": {'your_key'},
	"X-RapidAPI-Host": {'your_host'}
}

##lIST OF SKILLS
words = ['ETL','Orchestration', 'modeling', 'python', 
         'sql','pandas','docker','aws','gcp','google cloud',
         'postgres','mongodb','spark','jira','databricks',
         'azure','dbt','amazon','s3','linux','hadoop','kubernetes',
         'hbase','hive','fivetran','mage','airflow','ci/cd','elt']

acronyms = ['sql','dbt','elt','etl','aws','gcp'] #Acronyms from skills list that would need to be made uppercase

#
employer_website = []
job_id = []
job_employment_type = []
job_title = []
job_apply_link=[]
job_description=[]
job_city=[]
job_country =[]
job_posted_at_date =[]
employer_company_type =[]



#create a function to extract skills from an input
def extract_skills(c):
    skills = []
    for i in words:
        if i.lower() in c.lower():
            if i.lower() in acronyms:
                skills.append(i.upper())
            else: skills.append(i.title())
    return skills





def get_data_from_api():
    response = requests.get(url, headers=headers, params=querystring)
    data = response.json()
    return data



def extract_relevant_records_from_overall_data(data):

    for i in range(len(data['data'])):
        employer_website.append(data['data'][i]['employer_website'])
        job_id.append(data['data'][i]['job_id'])
        job_employment_type.append(data['data'][i]['job_employment_type'])
        job_title.append(data['data'][i]['job_title'])
        job_apply_link.append(data['data'][i]['job_apply_link'])
        job_description.append(data['data'][i]['job_description'])
        job_city.append(data['data'][i]['job_city'])
        job_country.append(data['data'][i]['job_country'])
        job_posted_at_date.append(data['data'][i]['job_posted_at_datetime_utc'][:10])
        employer_company_type.append(data['data'][i]['employer_company_type'])





def translate_extractions_to_dataframe_and_transform():
    #placing values into columns
    rapid_dict = {
                    'job_id': job_id,
                    'employer_website':employer_website,
                    'job_employment_type':job_employment_type,
                    'job_title':job_title,
                    'job_apply_link':job_apply_link,
                    'job_description':job_description,
                    'job_city':job_city,
                    'job_country':job_country,
                    'job_posted_at_date':job_posted_at_date,
                    'employer_company_type':employer_company_type        

                 }
    job_df = pd.DataFrame(rapid_dict)#convert to dataframe
    
    #convert date column datatype from string to datetime
    job_df['job_posted_at_date'] = pd.to_datetime(job_df['job_posted_at_date'])
    
    #Add a new column in the dataframe and extract skills from the job_description column
    #using the job_description column as an input in the extract_skills function
    job_df['skillset'] = job_df['job_description'].apply(lambda x: extract_skills(x))
    
    #CHANGE THE POSITION OF THE SKILLSET COLUMN FROM LAST TO AFTER THE JOB DESCRIPTION COLUMN
    
    #remove the skillset column and save it in a variable
    skillset_col = job_df.pop('skillset')
    
    # insert column using insert(position,column_name,skillset_col) function
    job_df.insert(6, 'skillset', skillset_col)
  
    return job_df




extract_relevant_records_from_overall_data(get_data_from_api())
translate_extractions_to_dataframe_and_transform()
# Out:
#                       job_id              employer_website  \
# 0   _4eEPO3CyekAAAAAAAAAAA==          http://www.veeva.com
# 1   Ym__TbIa2mEAAAAAAAAAAA==                          None
# 2   8ZgjmvZIlL8AAAAAAAAAAA==         http://citylitics.com
# 3   vIogYISqBA8AAAAAAAAAAA==  http://www.junipersquare.com
# 4   56gxLd9v-awAAAAAAAAAAA==                          None
# 5   MJFRO2LK_aYAAAAAAAAAAA==                          None
# 6   _Jb_wUSnIDgAAAAAAAAAAA==   http://www.bosautomation.ca
# 7   ZJqhTNEpPXkAAAAAAAAAAA==     http://www.spinmaster.com
# 8   cfBZhWMJN4IAAAAAAAAAAA==        http://www.wattpad.com
# 9   xFeP736E3OQAAAAAAAAAAA==                          None
# 10  TJ9tSVD1FF0AAAAAAAAAAA==         http://www.geotab.com
# 11  7bDlRbQWgSIAAAAAAAAAAA==                          None
# 12  MTe_5qtDFEMAAAAAAAAAAA==          http://www.wysdom.ai
# 13  N_IYA5VFMREAAAAAAAAAAA==           http://talkatoo.com
# 14  0sESFsm5zRUAAAAAAAAAAA==           http://www.bench.co
# 15  deyrIk2KIQEAAAAAAAAAAA==           http://biorender.io
# 16  kGHF8cDkHFgAAAAAAAAAAA==         http://www.scribd.com
# 17  wrBv0yu3UlQAAAAAAAAAAA==                          None
# 18  BV1bqET5zzIAAAAAAAAAAA==   http://www.fpt-software.com
# 19  cYZrZYkoukcAAAAAAAAAAA==                          None
# 20  Q_dAhgkCGYYAAAAAAAAAAA==      http://www.railvision.ca
# 21  jlJ3UVruwPAAAAAAAAAAAA==                          None
# 22  VSiI5J6PW0YAAAAAAAAAAA==                          None
# 23  4aYmR6yntOoAAAAAAAAAAA==          http://www.block.xyz
# 24  _IXJPz0_9gQAAAAAAAAAAA==      http://www.versaterm.com
# 25  Z-8BH5WgNAIAAAAAAAAAAA==                          None
# 26  Ps2GkPqQO9MAAAAAAAAAAA==           http://biorender.io
# 27  bUj2-NWxpwkAAAAAAAAAAA==         http://www.tucows.com
# 28  mqypg1vqNZIAAAAAAAAAAA==     http://www.touchtunes.com
# 29  60CdEW6cY8QAAAAAAAAAAA==                          None
#
#    job_employment_type                                          job_title  \
# 0             FULLTIME                                      Data Engineer
# 1             FULLTIME                              Data Engineer, Remote
# 2             FULLTIME                                      Data Engineer
# 3             FULLTIME                        Software Engineer II (Data)
# 4             FULLTIME                                      Data Engineer
# 5             FULLTIME                                      Data Engineer
# 6             FULLTIME                             Data Engineer (Remote)
# 7             FULLTIME                                      Data Engineer
# 8             FULLTIME                                      Data Engineer
# 9             FULLTIME                                      Data Engineer
# 10            FULLTIME                                 Data Ops Developer
# 11            FULLTIME  Data Engineering Advanced Accelerator Program ...
# 12            FULLTIME                                      Data Engineer
# 13            FULLTIME                          Machine Learning Engineer
# 14            FULLTIME                     Manager, Analytics Engineering
# 15            FULLTIME                          Engineering Leader (Data)
# 16            FULLTIME                 Analytics Engineer, Paid Marketing
# 17            FULLTIME                         Data Integrations Engineer
# 18            FULLTIME                          Machine Learning Engineer
# 19            FULLTIME                            Software Engineer, Data
# 20            FULLTIME                     Data Analyst Developer(Remote)
# 21            FULLTIME                          Machine Learning Engineer
# 22            FULLTIME      Software Engineer, Data Governance Foundation
# 23            FULLTIME      Software Engineer, Data Governance Foundation
# 24            FULLTIME                          Product Software Engineer
# 25            FULLTIME                   Machine Learning Engineer, Model
# 26            FULLTIME                                Data Science Leader
# 27            FULLTIME                                   Jr. Data Analyst
# 28            FULLTIME                               Ingénieur de données
# 29            FULLTIME         Ingénieur de données/Ingénieure de données
#
#                                        job_apply_link  \
# 0   https://www.ziprecruiter.com/c/Veeva-Systems/J...
# 1   https://ca.linkedin.com/jobs/view/data-enginee...
# 2        https://ai-jobs.net/job/63401-data-engineer/
# 3   https://ca.linkedin.com/jobs/view/software-eng...
# 4   https://www.glassdoor.ca/job-listing/data-engi...
# 5   https://remoteworkers.net/remote-jobs/data-sci...
# 6   https://pangian.com/job/data-engineer-remote-100/
# 7   https://ca.linkedin.com/jobs/view/data-enginee...
# 8   https://jobgether.com/offer/64c49600c663cc5c9c...
# 9   https://remoteworkers.net/remote-jobs/data-sci...
# 10  https://www.recruit.net/job/data-ops-jobs/40CB...
# 11  https://www.works.so/remote-jobs/data-engineer...
# 12  https://www.glassdoor.ca/job-listing/data-engi...
# 13  https://www.ziprecruiter.com/c/Talkatoo/Job/Ma...
# 14  https://emplois.ca.indeed.com/viewjob?jk=2df76...
# 15  https://jobs.bios.community/companies/biorende...
# 16  https://ca.linkedin.com/jobs/view/analytics-en...
# 17  https://www.ventureloop.com/ventureloop/job/25...
# 18  https://ca.linkedin.com/jobs/view/machine-lear...
# 19  https://www.glassdoor.ca/job-listing/software-...
# 20  https://www.ziprecruiter.com/c/RailVision-Anal...
# 21  https://www.glassdoor.ca/job-listing/machine-l...
# 22  https://www.eluta.ca/spl/software-engineer-dat...
# 23  https://jobgether.com/offer/64d58195197b479913...
# 24  https://jobgether.com/offer/64d13ef546532eb1b8...
# 25  https://www.learn4good.com/jobs/online_remote/...
# 26  https://www.ycombinator.com/companies/biorende...
# 27  https://www.recruit.net/job/data-analyst-jobs/...
# 28  https://fr.glassdoor.ca/job-listing/ing%C3%A9n...
# 29  https://ca.linkedin.com/jobs/view/ing%C3%A9nie...
#
#                                       job_description  \
# 0   Veeva Systems is a mission-driven organization...
# 1   A smile can be transformative. Byte was founde...
# 2   About CityliticsCitylitics delivers predictive...
# 3   About Juniper Square\n\nOur mission is to unlo...
# 4   ABOUT YOU: You are a junior/intermediate data ...
# 5   We are looking for a Data Engineer to design, ...
# 6   100% remote job\n\nData Engineer | BOS Innovat...
# 7   Please Note: If you are a current Spin Master ...
# 8   This a Full Remote job, the offer is available...
# 9   JOB SUMMARY\n\nAs a Data Engineer at MFI, you ...
# 10  Who we are:\n\nGeotab ® is a global leader in ...
# 11  Latin America /\n\nTraining Program /\n\nFull-...
# 12  They say you only get one chance to make a gre...
# 13  Salary:\n\nmachine-learningTalkatoo is reinven...
# 14  What's Bench? Visit Bench's latest news to see...
# 15  At BioRender, our mission is to accelerate the...
# 16  At Scribd (pronounced “scribbed”), we believe ...
# 17  About Enable:\n\nMarket forces are dramaticall...
# 18  ▪ Refactor prototypes of predictive models int...
# 19  Fathom is on a mission to use AI to understand...
# 20  Suffering from climate anxiety? So are we. Tha...
# 21  We are looking for a highly capable machine le...
# 22  Job Description\n\nGood decision-making is onl...
# 23  This a Full Remote job, the offer is available...
# 24  This a Full Remote job, the offer is available...
# 25  Position: Machine Learning Engineer, Large Mod...
# 26  At BioRender, our mission is to accelerate the...
# 27  Tucows (NASDAQ:TCX, TSX:TC) is possibly the bi...
# 28  • ️ Pôle technologique hybride de Montréal\n• ...
# 29  Poste permanent\n\n40h/semaine\n\nAstek recher...
#
#                                              skillset   job_city job_country  \
# 0                                          [SQL, AWS]    Toronto          CA
# 1               [ETL, SQL, Azure, DBT, Fivetran, ELT]       None          CA
# 2   [ETL, Orchestration, Python, SQL, Docker, Goog...       None        None
# 3    [ETL, Modeling, Python, SQL, AWS, Postgres, ELT]    Toronto          CA
# 4                        [Modeling, Python, SQL, AWS]       None          CA
# 5                                          [SQL, DBT]       None          KH
# 6                 [ETL, Modeling, Python, SQL, Azure]       None          CA
# 7                      [Python, SQL, AWS, GCP, Azure]    Toronto          CA
# 8                          [ETL, Python, Spark, Hive]   Winnipeg          CA
# 9                             [ETL, Python, SQL, AWS]       None          ZA
# 10  [ETL, Orchestration, Modeling, Python, SQL, Do...       None          CA
# 11                       [Python, SQL, Spark, Hadoop]       None        None
# 12  [ETL, Python, SQL, Pandas, Docker, AWS, GCP, P...       None          CA
# 13                              [Python, SQL, Pandas]    Halifax          CA
# 14                          [SQL, AWS, DBT, Fivetran]  Vancouver          CA
# 15              [Python, SQL, Spark, Hadoop, Airflow]       None          CA
# 16                                      [Python, SQL]       None          CA
# 17                             [ETL, SQL, AWS, Azure]    Toronto          CA
# 18  [Python, SQL, Pandas, Spark, Databricks, Hadoo...       None          CA
# 19                    [Python, Spark, Amazon, Hadoop]  Vancouver          CA
# 20               [Python, SQL, Pandas, AWS, Postgres]   Montréal          CA
# 21                           [Modeling, Python, Mage]       None          CA
# 22  [Python, SQL, Docker, AWS, GCP, Databricks, Ku...    Toronto          CA
# 23  [Python, SQL, Docker, AWS, GCP, Databricks, Ku...       None          CA
# 24  [SQL, Docker, AWS, Postgres, Azure, Linux, Kub...   Winnipeg          CA
# 25                                       [AWS, Azure]    Toronto          CA
# 26                                         [Modeling]    Toronto          CA
# 27                                              [SQL]    Toronto          CA
# 28  [Python, SQL, Docker, AWS, Spark, Databricks, ...   Montréal          CA
# 29         [ETL, Python, SQL, AWS, DBT, Airflow, ELT]   Montréal          CA
#
#    job_posted_at_date employer_company_type
# 0          2023-08-16     Computer Services
# 1          2023-08-17                  None
# 2          2023-08-11                  None
# 3          2023-08-17                  None
# 4          2023-08-09                  None
# 5          2023-07-26                  None
# 6          2023-07-22                  None
# 7          2023-08-09         Entertainment
# 8          2023-07-29                  None
# 9          2023-07-26                  None
# 10         2023-08-16         Manufacturing
# 11         2023-08-02                  None
# 12         2023-08-10                  None
# 13         2023-08-18                  None
# 14         2023-07-26            Consulting
# 15         2023-08-02                  None
# 16         2023-08-12           Information
# 17         2023-08-04                  None
# 18         2023-08-04     Computer Services
# 19         2023-08-03                  None
# 20         2023-08-09                  None
# 21         2023-07-19                  None
# 22         2023-08-08                  None
# 23         2023-08-10           Information
# 24         2023-08-06           Information
# 25         2023-08-08           Information
# 26         2023-08-10                  None
# 27         2023-08-17           Information
# 28         2023-07-20                  None
# 29         2023-08-01                  None

# %%
#Using length function to ensure if the total number of dataset output was retrieve based on the modification criteria
len(get_data_from_api()['data'])
# Out:
# 30

# %% [markdown]
# # challenges
#
#
# ## the Modification output showed 30 job vacancies was retrieve, rather than at least 100 job vacancies to meet the specified criteria from the extracted data.
#
#
# ## After Analysing the issues with the modification, while only filtering the candidates with under 3 years of experience, it only retrieve 36 output.  also filtering only the job remote true, it retrieve 165 output from the extracted data.
#
#
# # Conclusion
#
# ## The candidates with under 3 years of experience is the reason why the output to retrieve at least 100 job vacancies reduces, because there's less data to retrieve.
